# %%
import pandas as pd
import numpy as np
import os
import csv
import shutil
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.optimizers.legacy import Adam, SGD
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
# Define the directory paths
dir_paths = ["Dataset/ECG Images of COVID-19 Patients (250)", "Dataset/ECG Images of Myocardial Infarction Patients (77)", "Dataset/ECG Images of Patient that have abnormal heart beats (548)", "Dataset/ECG Images of Patient that have History of MI (203)", "Dataset/Normal Person ECG Images (859)"]

# Create a list to store the image filenames
image_filenames = []

# Loop through the directories and add the image filenames to the list
for dir_path in dir_paths:
    for filename in os.listdir(dir_path):
        if filename.endswith(".jpg") or filename.endswith(".png"):
            image_filenames.append(filename)

# Create a CSV file and write the image filenames and label "0" to it
with open("image_labels.csv", mode="w", newline="") as csv_file:
    writer = csv.writer(csv_file)
    writer.writerow(["filename", "label"])
    for image_filename in image_filenames:
        if "Normal" in image_filename:
            writer.writerow([image_filename, "0"])
        else:
            writer.writerow([image_filename, "1"])

# %%
import os
import cv2

# directory containing the images to be cropped
input_dir = "Dataset/ECG Images of COVID-19 Patients (250)/"

# loop through all files in the directory
for filename in os.listdir(input_dir):
    # check if the file is an image file
    if filename.endswith(".jpg"):
        # read the image
        img = cv2.imread(os.path.join(input_dir, filename))
        
        # perform the cropping operation
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        th, threshed = cv2.threshold(gray, 240, 255, cv2.THRESH_BINARY_INV)
        kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (11,11))
        morphed = cv2.morphologyEx(threshed, cv2.MORPH_CLOSE, kernel)
        cnts = cv2.findContours(morphed, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)[-2]
        cnt = sorted(cnts, key=cv2.contourArea)[-1]
        x,y,w,h = cv2.boundingRect(cnt)
        dst = img[y:y+h, x:x+w]
        
        # save the cropped image with the same filename
        cv2.imwrite(os.path.join(input_dir, filename), dst)

# %%
# define paths
source_folder = 'Dataset'
destination_folder = 'images'

# create destination folder if not exists
if not os.path.exists(destination_folder):
    os.makedirs(destination_folder)

# loop through subdirectories
for subdir in os.listdir(source_folder):
    subdir_path = os.path.join(source_folder, subdir)
    
    # check if it is a directory and not a file
    if os.path.isdir(subdir_path) and "ECG" in subdir_path:
        print(subdir)
        
        # loop through files in subdirectory
        for file in os.listdir(subdir_path):
            file_path = os.path.join(subdir_path, file)
            
            # copy file to destination folder
            shutil.copy(file_path, destination_folder)
# Out:
# ECG Images of COVID-19 Patients (250)
# ECG Images of Patient that have History of MI (203)
# ECG Images of Patient that have abnormal heart beats (548)
# Normal Person ECG Images (859)
# ECG Images of Myocardial Infarction Patients (77)

# %%
# Set random seed for reproducibility
np.random.seed(42)

# Load CSV file containing image filenames and labels
df = pd.read_csv('image_labels.csv')
df["label"] = df["label"].astype(str)

# %%
# Split dataset into training and testing sets
train_df, test_df = train_test_split(df, test_size=0.2, stratify=df['label'], random_state=42)

# %%
# Create directories for train, validation, and test sets
train_dir = 'train'
os.makedirs(train_dir, exist_ok=True)

test_dir = 'test'
os.makedirs(test_dir, exist_ok=True)

# %%
# Move images to respective directories based on the split
for i, row in train_df.iterrows():
    src = 'images/' + row['filename']
    dst = train_dir + '/' + row['filename']
    shutil.copyfile(src, dst)

for i, row in test_df.iterrows():
    src = 'images/' + row['filename']
    dst = test_dir + '/' + row['filename']
    shutil.copyfile(src, dst)

# %%
# Data augmentation for training set
train_datagen = ImageDataGenerator(rescale=1./255,
                                   rotation_range=20,
                                   width_shift_range=0.2,
                                   height_shift_range=0.2,
                                   shear_range=0.2,
                                   zoom_range=0.2,
                                   horizontal_flip=True,
                                   vertical_flip=True,
                                   preprocessing_function=preprocess_input)

# No data augmentation for testing set, only rescaling
test_datagen = ImageDataGenerator(rescale=1./255,
                                  preprocessing_function=preprocess_input)

# %%
# Define batch size
batch_size = 32

# Set target image size
target_size = (224, 224)

# %%
# Create training and testing generators
train_generator = train_datagen.flow_from_dataframe(dataframe=train_df,
                                                    directory=train_dir,
                                                    x_col='filename',
                                                    y_col='label',
                                                    target_size=target_size,
                                                    batch_size=batch_size,
                                                    class_mode='binary')

test_generator = test_datagen.flow_from_dataframe(dataframe=test_df,
                                                  directory=test_dir,
                                                  x_col='filename',
                                                  y_col='label',
                                                  target_size=target_size,
                                                  batch_size=batch_size,
                                                  class_mode='binary')
# Out:
# Found 1541 validated image filenames belonging to 2 classes.
# Found 386 validated image filenames belonging to 2 classes.

# %%
# Build CNN model
model = Sequential()

model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(224, 224, 3)))
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))

model.add(Flatten())

model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(1, activation='sigmoid'))

# %%
# Compile model
#KerasClassifier(model = model, optimizer=tf.keras.optimizers.Adam(), epochs=100, verbose=0)
from tensorflow import keras
adam = keras.optimizers.Adam()

model.compile(loss='binary_crossentropy',
              optimizer=adam,
              metrics=['accuracy'])

# Define callbacks
early_stop = EarlyStopping(monitor='val_loss', patience=5)
best_model = ModelCheckpoint('best_model.h5', monitor='val_loss', save_best_only=True)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.

# %%
# Train model
history = model.fit(train_generator,
                    steps_per_epoch=len(train_generator),
                    epochs=20,
                    validation_data=test_generator,
                    validation_steps=len(test_generator),
                    callbacks=[early_stop, best_model])
# Out:
# Epoch 1/20
# 49/49 [==============================] - 55s 1s/step - loss: 0.7012 - accuracy: 0.5490 - val_loss: 0.6838 - val_accuracy: 0.5544
# Epoch 2/20
# 49/49 [==============================] - 57s 1s/step - loss: 0.6655 - accuracy: 0.5548 - val_loss: 0.9217 - val_accuracy: 0.5544
# Epoch 3/20
# 49/49 [==============================] - 57s 1s/step - loss: 0.6277 - accuracy: 0.6080 - val_loss: 0.5722 - val_accuracy: 0.6244
# Epoch 4/20
# 49/49 [==============================] - 59s 1s/step - loss: 0.5775 - accuracy: 0.6671 - val_loss: 1.7707 - val_accuracy: 0.5389
# Epoch 5/20
# 49/49 [==============================] - 62s 1s/step - loss: 0.5368 - accuracy: 0.6885 - val_loss: 0.8863 - val_accuracy: 0.5829
# Epoch 6/20
# 49/49 [==============================] - 60s 1s/step - loss: 0.5311 - accuracy: 0.7151 - val_loss: 0.5177 - val_accuracy: 0.7461
# Epoch 7/20
# 49/49 [==============================] - 60s 1s/step - loss: 0.4960 - accuracy: 0.7313 - val_loss: 2.7318 - val_accuracy: 0.5440
# Epoch 8/20
# 49/49 [==============================] - 63s 1s/step - loss: 0.5296 - accuracy: 0.7145 - val_loss: 0.9614 - val_accuracy: 0.6218
# Epoch 9/20
# 49/49 [==============================] - 63s 1s/step - loss: 0.4881 - accuracy: 0.7456 - val_loss: 0.5685 - val_accuracy: 0.7306
# Epoch 10/20
# 49/49 [==============================] - 62s 1s/step - loss: 0.4899 - accuracy: 0.7326 - val_loss: 0.8133 - val_accuracy: 0.7073
# Epoch 11/20
# 49/49 [==============================] - 62s 1s/step - loss: 0.4837 - accuracy: 0.7534 - val_loss: 0.5857 - val_accuracy: 0.7306

# %%
# Evaluate model on testing set
test_loss, test_acc = model.evaluate(test_generator, steps=len(test_generator))
print('Test accuracy:', test_acc)

# Save model
model.save('my_model.h5')

# Save training history to CSV file
history_df = pd.DataFrame(history.history)
history_df.to_csv('training_history.csv', index=False)
# Out:
# 13/13 [==============================] - 9s 644ms/step - loss: 0.7411 - accuracy: 0.6736
# Test accuracy: 0.6735751032829285

# %%
y_pred = model.predict(X_test)
y_pred_binary = np.round(y_pred)

# %%
import cv2
import os
import tensorflow as tf
import numpy as np

# define the categories
categories = ['Low Risk', 'High Risk']

# define the path to the directory containing images
img_dir = 'Test/'

# loop through the images and make predictions
for img_name in os.listdir(img_dir):
    img_path = os.path.join(img_dir, img_name)
    print(img_name)
    # read the image
    img = cv2.imread(img_path)
    
    # resize the image
    img = cv2.resize(img, (224, 224))
    img = np.expand_dims(img, axis=0)

    # make a prediction
    probs = model.predict(img)
    predictions = np.where(probs > 0.5, 1, 0)
    print(prediction)
    pred_class = categories[int((prediction[0]))]
    #img = cv2.cvtColor(img, cv2.COLOR_GRAY2BGR)
    #cv2.imshow("img_name", img)
    print(f'Prediction for {img_name}: {pred_class}')
# Out:
# Normal (325).jpg
# 1/1 [==============================] - 0s 20ms/step
# [[0.2713841]]
# Prediction for Normal (325).jpg: Low Risk
# HB   (141).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for HB   (141).jpg: Low Risk
# PMI  (27).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for PMI  (27).jpg: Low Risk
# Normal (260).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Normal (260).jpg: Low Risk
# HB (185).jpg
# 1/1 [==============================] - 0s 17ms/step
# [[0.2713841]]
# Prediction for HB (185).jpg: Low Risk
# COVID  (8).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for COVID  (8).jpg: Low Risk
# HB (490).jpg
# 1/1 [==============================] - 0s 17ms/step
# [[0.2713841]]
# Prediction for HB (490).jpg: Low Risk
# HB   (116).jpg
# 1/1 [==============================] - 0s 20ms/step
# [[0.2713841]]
# Prediction for HB   (116).jpg: Low Risk
# HB (428).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for HB (428).jpg: Low Risk
# PMI (179).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for PMI (179).jpg: Low Risk
# Binder1_Page_119.jpg
# 1/1 [==============================] - 0s 17ms/step
# [[0.2713841]]
# Prediction for Binder1_Page_119.jpg: Low Risk
# Normal (364).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Normal (364).jpg: Low Risk
# HB (202).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for HB (202).jpg: Low Risk
# Binder1_Page_092.jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Binder1_Page_092.jpg: Low Risk
# Normal (13).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Normal (13).jpg: Low Risk
# Binder1_Page_086.jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Binder1_Page_086.jpg: Low Risk
# PMI (77).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for PMI (77).jpg: Low Risk
# Binder1_Page_045.jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Binder1_Page_045.jpg: Low Risk
# PMI (180).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for PMI (180).jpg: Low Risk
# Normal (333).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Normal (333).jpg: Low Risk
# Normal (299).jpg
# 1/1 [==============================] - 0s 18ms/step
# [[0.2713841]]
# Prediction for Normal (299).jpg: Low Risk
# PMI (138).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for PMI (138).jpg: Low Risk
# PMI  (1).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for PMI  (1).jpg: Low Risk
# HB   (18).jpg
# 1/1 [==============================] - 0s 17ms/step
# [[0.2713841]]
# Prediction for HB   (18).jpg: Low Risk
# Normal (431).jpg
# 1/1 [==============================] - 0s 20ms/step
# [[0.2713841]]
# Prediction for Normal (431).jpg: Low Risk
# HB (412).jpg
# 1/1 [==============================] - 0s 19ms/step
# [[0.2713841]]
# Prediction for HB (412).jpg: Low Risk
# PMI (143).jpg
# 1/1 [==============================] - 0s 17ms/step
# [[0.2713841]]
# Prediction for PMI (143).jpg: Low Risk
# Binder1_Page_078.jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Binder1_Page_078.jpg: Low Risk
# HB (296).jpg
# 1/1 [==============================] - 0s 17ms/step
# [[0.2713841]]
# Prediction for HB (296).jpg: Low Risk
# HB (279).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for HB (279).jpg: Low Risk
# Normal (68).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Normal (68).jpg: Low Risk
# Binder1_Page_087.jpg
# 1/1 [==============================] - 0s 17ms/step
# [[0.2713841]]
# Prediction for Binder1_Page_087.jpg: Low Risk
# Normal (489).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Normal (489).jpg: Low Risk
# Normal (173).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Normal (173).jpg: Low Risk
# Binder1_Page_093.jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Binder1_Page_093.jpg: Low Risk
# Normal (470).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Normal (470).jpg: Low Risk
# PMI (102).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for PMI (102).jpg: Low Risk
# PMI (155).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for PMI (155).jpg: Low Risk
# Normal (562).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Normal (562).jpg: Low Risk
# HB (473).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for HB (473).jpg: Low Risk
# PMI (122).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for PMI (122).jpg: Low Risk
# HB   (96).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for HB   (96).jpg: Low Risk
# HB (536).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for HB (536).jpg: Low Risk
# Normal (329).jpg
# 1/1 [==============================] - 0s 17ms/step
# [[0.2713841]]
# Prediction for Normal (329).jpg: Low Risk
# PMI (175).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for PMI (175).jpg: Low Risk
# Normal (542).jpg
# 1/1 [==============================] - 0s 17ms/step
# [[0.2713841]]
# Prediction for Normal (542).jpg: Low Risk
# Normal (554).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Normal (554).jpg: Low Risk
# PMI (163).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for PMI (163).jpg: Low Risk
# Normal (807).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Normal (807).jpg: Low Risk
# Binder1_Page_046.jpg
# 1/1 [==============================] - 0s 17ms/step
# [[0.2713841]]
# Prediction for Binder1_Page_046.jpg: Low Risk
# Binder1_Page_052.jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Binder1_Page_052.jpg: Low Risk
# Normal (153).jpg
# 1/1 [==============================] - 0s 17ms/step
# [[0.2713841]]
# Prediction for Normal (153).jpg: Low Risk
# HB   (14).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for HB   (14).jpg: Low Risk
# Normal (651).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Normal (651).jpg: Low Risk
# HB (367).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for HB (367).jpg: Low Risk
# HB (388).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for HB (388).jpg: Low Risk
# HB (222).jpg
# 1/1 [==============================] - 0s 17ms/step
# [[0.2713841]]
# Prediction for HB (222).jpg: Low Risk
# HB   (43).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for HB   (43).jpg: Low Risk
# Normal (190).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Normal (190).jpg: Low Risk
# Binder1_Page_053.jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Binder1_Page_053.jpg: Low Risk
# Binder1_Page_047.jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Binder1_Page_047.jpg: Low Risk
# Normal (256).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Normal (256).jpg: Low Risk
# PMI  (11).jpg
# 1/1 [==============================] - 0s 17ms/step
# [[0.2713841]]
# Prediction for PMI  (11).jpg: Low Risk
# Binder1_Page_090.jpg
# 1/1 [==============================] - 0s 17ms/step
# [[0.2713841]]
# Prediction for Binder1_Page_090.jpg: Low Risk
# Normal (743).jpg
# 1/1 [==============================] - 0s 17ms/step
# [[0.2713841]]
# Prediction for Normal (743).jpg: Low Risk
# Binder1_Page_084.jpg
# 1/1 [==============================] - 0s 17ms/step
# [[0.2713841]]
# Prediction for Binder1_Page_084.jpg: Low Risk
# Binder1_Page_127.jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Binder1_Page_127.jpg: Low Risk
# Normal (539).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Normal (539).jpg: Low Risk
# Normal (755).jpg
# 1/1 [==============================] - 0s 17ms/step
# [[0.2713841]]
# Prediction for Normal (755).jpg: Low Risk
# Normal (305).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Normal (305).jpg: Low Risk
# Normal (217).jpg
# 1/1 [==============================] - 0s 17ms/step
# [[0.2713841]]
# Prediction for Normal (217).jpg: Low Risk
# HB   (136).jpg
# 1/1 [==============================] - 0s 17ms/step
# [[0.2713841]]
# Prediction for HB   (136).jpg: Low Risk
# Normal (352).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Normal (352).jpg: Low Risk
# Normal (702).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Normal (702).jpg: Low Risk
# HB (370).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for HB (370).jpg: Low Risk
# MI (16).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for MI (16).jpg: Low Risk
# Binder1_Page_123.jpg
# 1/1 [==============================] - 0s 17ms/step
# [[0.2713841]]
# Prediction for Binder1_Page_123.jpg: Low Risk
# Normal (538).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Normal (538).jpg: Low Risk
# HB (331).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for HB (331).jpg: Low Risk
# PMI  (10).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for PMI  (10).jpg: Low Risk
# Binder1_Page_080.jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Binder1_Page_080.jpg: Low Risk
# HB (274).jpg
# 1/1 [==============================] - 0s 17ms/step
# [[0.2713841]]
# Prediction for HB (274).jpg: Low Risk
# Normal (484).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Normal (484).jpg: Low Risk
# PMI (119).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for PMI (119).jpg: Low Risk
# PMI (56).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for PMI (56).jpg: Low Risk
# Normal (200).jpg
# 1/1 [==============================] - 0s 17ms/step
# [[0.2713841]]
# Prediction for Normal (200).jpg: Low Risk
# HB   (121).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for HB   (121).jpg: Low Risk
# Normal (596).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Normal (596).jpg: Low Risk
# MI (57).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for MI (57).jpg: Low Risk
# HB (258).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for HB (258).jpg: Low Risk
# Normal (49).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Normal (49).jpg: Low Risk
# PMI (135).jpg
# 1/1 [==============================] - 0s 17ms/step
# [[0.2713841]]
# Prediction for PMI (135).jpg: Low Risk
# PMI (95).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for PMI (95).jpg: Low Risk
# Binder1_Page_056.jpg
# 1/1 [==============================] - 0s 18ms/step
# [[0.2713841]]
# Prediction for Binder1_Page_056.jpg: Low Risk
# Binder1_Page_042.jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Binder1_Page_042.jpg: Low Risk
# Binder1_Page_095.jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Binder1_Page_095.jpg: Low Risk
# Binder1_Page_081.jpg
# 1/1 [==============================] - 0s 17ms/step
# [[0.2713841]]
# Prediction for Binder1_Page_081.jpg: Low Risk
# Binder1_Page_122.jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Binder1_Page_122.jpg: Low Risk
# PMI (83).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for PMI (83).jpg: Low Risk
# MI (9).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for MI (9).jpg: Low Risk
# PMI (174).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for PMI (174).jpg: Low Risk
# Normal (543).jpg
# 1/1 [==============================] - 0s 17ms/step
# [[0.2713841]]
# Prediction for Normal (543).jpg: Low Risk
# HB (425).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for HB (425).jpg: Low Risk
# Normal (282).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Normal (282).jpg: Low Risk
# Normal (778).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Normal (778).jpg: Low Risk
# Normal (797).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Normal (797).jpg: Low Risk
# HB (188).jpg
# 1/1 [==============================] - 0s 17ms/step
# [[0.2713841]]
# Prediction for HB (188).jpg: Low Risk
# HB   (97).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for HB   (97).jpg: Low Risk
# HB (537).jpg
# 1/1 [==============================] - 0s 17ms/step
# [[0.2713841]]
# Prediction for HB (537).jpg: Low Risk
# Normal (426).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Normal (426).jpg: Low Risk
# HB (540).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for HB (540).jpg: Low Risk
# HB (393).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for HB (393).jpg: Low Risk
# Normal (28).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Normal (28).jpg: Low Risk
# PMI (115).jpg
# 1/1 [==============================] - 0s 18ms/step
# [[0.2713841]]
# Prediction for PMI (115).jpg: Low Risk
# HB (297).jpg
# 1/1 [==============================] - 0s 19ms/step
# [[0.2713841]]
# Prediction for HB (297).jpg: Low Risk
# HB   (19).jpg
# 1/1 [==============================] - 0s 21ms/step
# [[0.2713841]]
# Prediction for HB   (19).jpg: Low Risk
# Normal (1).jpg
# 1/1 [==============================] - 0s 18ms/step
# [[0.2713841]]
# Prediction for Normal (1).jpg: Low Risk
# HB (385).jpg
# 1/1 [==============================] - 0s 23ms/step
# [[0.2713841]]
# Prediction for HB (385).jpg: Low Risk
# Normal (719).jpg
# 1/1 [==============================] - 0s 19ms/step
# [[0.2713841]]
# Prediction for Normal (719).jpg: Low Risk
# HB (192).jpg
# 1/1 [==============================] - 0s 18ms/step
# [[0.2713841]]
# Prediction for HB (192).jpg: Low Risk
# PMI (139).jpg
# 1/1 [==============================] - 0s 23ms/step
# [[0.2713841]]
# Prediction for PMI (139).jpg: Low Risk
# HB (487).jpg
# 1/1 [==============================] - 0s 19ms/step
# [[0.2713841]]
# Prediction for HB (487).jpg: Low Risk
# HB (254).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for HB (254).jpg: Low Risk
# Normal (332).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Normal (332).jpg: Low Risk
# HB (311).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for HB (311).jpg: Low Risk
# Binder1_Page_069.jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Binder1_Page_069.jpg: Low Risk
# HB   (35).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for HB   (35).jpg: Low Risk
# MI (77).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for MI (77).jpg: Low Risk
# Normal (12).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Normal (12).jpg: Low Risk
# Binder1_Page_082.jpg
# 1/1 [==============================] - 0s 17ms/step
# [[0.2713841]]
# Prediction for Binder1_Page_082.jpg: Low Risk
# PMI (99).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for PMI (99).jpg: Low Risk
# Normal (670).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Normal (670).jpg: Low Risk
# Normal (723).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Normal (723).jpg: Low Risk
# Normal (236).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Normal (236).jpg: Low Risk
# HB   (74).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for HB   (74).jpg: Low Risk
# HB   (140).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for HB   (140).jpg: Low Risk
# PMI  (26).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for PMI  (26).jpg: Low Risk
# Normal (261).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Normal (261).jpg: Low Risk
# PMI (124).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for PMI (124).jpg: Low Risk
# Normal (513).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Normal (513).jpg: Low Risk
# Normal (143).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Normal (143).jpg: Low Risk
# PMI (84).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for PMI (84).jpg: Low Risk
# Binder1_Page_152.jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Binder1_Page_152.jpg: Low Risk
# HB   (9).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for HB   (9).jpg: Low Risk
# PMI (165).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for PMI (165).jpg: Low Risk
# Normal (801).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Normal (801).jpg: Low Risk
# HB (208).jpg
# 1/1 [==============================] - 0s 17ms/step
# [[0.2713841]]
# Prediction for HB (208).jpg: Low Risk
# Binder1_Page_032.jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Binder1_Page_032.jpg: Low Risk
# HB   (69).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for HB   (69).jpg: Low Risk
# Normal (440).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Normal (440).jpg: Low Risk
# Normal (293).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Normal (293).jpg: Low Risk
# Normal (769).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Normal (769).jpg: Low Risk
# Normal (339).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Normal (339).jpg: Low Risk
# HB (418).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for HB (418).jpg: Low Risk
# Binder1_Page_231.jpg
# 1/1 [==============================] - 0s 17ms/step
# [[0.2713841]]
# Prediction for Binder1_Page_231.jpg: Low Risk
# Normal (196).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Normal (196).jpg: Low Risk
# Binder1_Page_027.jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Binder1_Page_027.jpg: Low Risk
# Normal (529).jpg
# 1/1 [==============================] - 0s 17ms/step
# [[0.2713841]]
# Prediction for Normal (529).jpg: Low Risk
# HB   (53).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for HB   (53).jpg: Low Risk
# Binder1_Page_153.jpg
# 1/1 [==============================] - 0s 17ms/step
# [[0.2713841]]
# Prediction for Binder1_Page_153.jpg: Low Risk
# Binder1_Page_147.jpg
# 1/1 [==============================] - 0s 17ms/step
# [[0.2713841]]
# Prediction for Binder1_Page_147.jpg: Low Risk
# HB   (167).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for HB   (167).jpg: Low Risk
# Normal (138).jpg
# 1/1 [==============================] - 0s 17ms/step
# [[0.2713841]]
# Prediction for Normal (138).jpg: Low Risk
# Normal (211).jpg
# 1/1 [==============================] - 0s 17ms/step
# [[0.2713841]]
# Prediction for Normal (211).jpg: Low Risk
# Normal (23).jpg
# 1/1 [==============================] - 0s 17ms/step
# [[0.2713841]]
# Prediction for Normal (23).jpg: Low Risk
# Normal (773).jpg
# 1/1 [==============================] - 0s 17ms/step
# [[0.2713841]]
# Prediction for Normal (773).jpg: Low Risk
# MI (31).jpg
# 1/1 [==============================] - 0s 17ms/step
# [[0.2713841]]
# Prediction for MI (31).jpg: Low Risk
# HB (357).jpg
# 1/1 [==============================] - 0s 17ms/step
# [[0.2713841]]
# Prediction for HB (357).jpg: Low Risk
# HB   (24).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for HB   (24).jpg: Low Risk
# MI (66).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for MI (66).jpg: Low Risk
# Binder1_Page_179.jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Binder1_Page_179.jpg: Low Risk
# Normal (698).jpg
# 1/1 [==============================] - 0s 17ms/step
# [[0.2713841]]
# Prediction for Normal (698).jpg: Low Risk
# HB (204).jpg
# 1/1 [==============================] - 0s 17ms/step
# [[0.2713841]]
# Prediction for HB (204).jpg: Low Risk
# HB (341).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for HB (341).jpg: Low Risk
# Binder1_Page_025.jpg
# 1/1 [==============================] - 0s 17ms/step
# [[0.2713841]]
# Prediction for Binder1_Page_025.jpg: Low Risk
# Binder1_Page_019.jpg
# 1/1 [==============================] - 0s 17ms/step
# [[0.2713841]]
# Prediction for Binder1_Page_019.jpg: Low Risk
# HB (253).jpg
# 1/1 [==============================] - 0s 18ms/step
# [[0.2713841]]
# Prediction for HB (253).jpg: Low Risk
# Normal (765).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Normal (765).jpg: Low Risk
# HB (316).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for HB (316).jpg: Low Risk
# Binder1_Page_227.jpg
# 1/1 [==============================] - 0s 25ms/step
# [[0.2713841]]
# Prediction for Binder1_Page_227.jpg: Low Risk
# Binder1_Page_233.jpg
# 1/1 [==============================] - 0s 17ms/step
# [[0.2713841]]
# Prediction for Binder1_Page_233.jpg: Low Risk
# HB (195).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for HB (195).jpg: Low Risk
# HB   (65).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for HB   (65).jpg: Low Risk
# HB (414).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for HB (414).jpg: Low Risk
# Binder1_Page_030.jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Binder1_Page_030.jpg: Low Risk
# Binder1_Page_024.jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Binder1_Page_024.jpg: Low Risk
# Normal (319).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Normal (319).jpg: Low Risk
# HB   (49).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for HB   (49).jpg: Low Risk
# Normal (78).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Normal (78).jpg: Low Risk
# HB (510).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for HB (510).jpg: Low Risk
# PMI (104).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for PMI (104).jpg: Low Risk
# Normal (533).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Normal (533).jpg: Low Risk
# HB (547).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for HB (547).jpg: Low Risk
# HB (403).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for HB (403).jpg: Low Risk
# PMI (152).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for PMI (152).jpg: Low Risk
# Normal (477).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Normal (477).jpg: Low Risk
# PMI (105).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for PMI (105).jpg: Low Risk
# HB (454).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for HB (454).jpg: Low Risk
# Binder1_Page_168.jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Binder1_Page_168.jpg: Low Risk
# HB (268).jpg
# 1/1 [==============================] - 0s 21ms/step
# [[0.2713841]]
# Prediction for HB (268).jpg: Low Risk
# Normal (174).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Normal (174).jpg: Low Risk
# HB (442).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for HB (442).jpg: Low Risk
# Normal (80).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Normal (80).jpg: Low Risk
# Binder1_Page_034.jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Binder1_Page_034.jpg: Low Risk
# Normal (820).jpg
# 1/1 [==============================] - 0s 23ms/step
# [[0.2713841]]
# Prediction for Normal (820).jpg: Low Risk
# Normal (123).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Normal (123).jpg: Low Risk
# HB (229).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for HB (229).jpg: Low Risk
# Binder1_Page_222.jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Binder1_Page_222.jpg: Low Risk
# Binder1_Page_236.jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Binder1_Page_236.jpg: Low Risk
# Binder1_Page_237.jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Binder1_Page_237.jpg: Low Risk
# Binder1_Page_223.jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Binder1_Page_223.jpg: Low Risk
# PMI  (6).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for PMI  (6).jpg: Low Risk
# HB (481).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for HB (481).jpg: Low Risk
# HB   (64).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for HB   (64).jpg: Low Risk
# HB (252).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for HB (252).jpg: Low Risk
# HB (317).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for HB (317).jpg: Low Risk
# Binder1_Page_035.jpg
# 1/1 [==============================] - 0s 17ms/step
# [[0.2713841]]
# Prediction for Binder1_Page_035.jpg: Low Risk
# HB (439).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for HB (439).jpg: Low Risk
# HB   (33).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for HB   (33).jpg: Low Risk
# PMI (70).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for PMI (70).jpg: Low Risk
# MI (3).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for MI (3).jpg: Low Risk
# Binder1_Page_155.jpg
# 1/1 [==============================] - 0s 17ms/step
# [[0.2713841]]
# Prediction for Binder1_Page_155.jpg: Low Risk
# HB   (25).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for HB   (25).jpg: Low Risk
# Binder1_Page_169.jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Binder1_Page_169.jpg: Low Risk
# PMI (191).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for PMI (191).jpg: Low Risk
# HB   (111).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for HB   (111).jpg: Low Risk
# Normal (660).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Normal (660).jpg: Low Risk
# HB (182).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for HB (182).jpg: Low Risk
# MI (30).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for MI (30).jpg: Low Risk
# Normal (267).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Normal (267).jpg: Low Risk
# PMI  (20).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for PMI  (20).jpg: Low Risk
# Normal (586).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Normal (586).jpg: Low Risk
# Normal (569).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Normal (569).jpg: Low Risk
# HB (321).jpg
# 1/1 [==============================] - 0s 17ms/step
# [[0.2713841]]
# Prediction for HB (321).jpg: Low Risk
# Normal (302).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Normal (302).jpg: Low Risk
# HB (264).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for HB (264).jpg: Low Risk
# HB   (52).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for HB   (52).jpg: Low Risk
# Normal (494).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Normal (494).jpg: Low Risk
# HB (337).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for HB (337).jpg: Low Risk
# Normal (601).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Normal (601).jpg: Low Risk
# HB (272).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for HB (272).jpg: Low Risk
# Normal (63).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Normal (63).jpg: Low Risk
# Normal (744).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Normal (744).jpg: Low Risk
# HB   (170).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for HB   (170).jpg: Low Risk
# Binder1_Page_037.jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Binder1_Page_037.jpg: Low Risk
# Binder1_Page_023.jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Binder1_Page_023.jpg: Low Risk
# Normal (656).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Normal (656).jpg: Low Risk
# HB (360).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for HB (360).jpg: Low Risk
# PMI (50).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for PMI (50).jpg: Low Risk
# HB   (127).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for HB   (127).jpg: Low Risk
# Normal (343).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Normal (343).jpg: Low Risk
# HB   (13).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for HB   (13).jpg: Low Risk
# HB (419).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for HB (419).jpg: Low Risk
# Binder1_Page_234.jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Binder1_Page_234.jpg: Low Risk
# Normal (787).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Normal (787).jpg: Low Risk
# Binder1_Page_208.jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Binder1_Page_208.jpg: Low Risk
# HB   (87).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for HB   (87).jpg: Low Risk
# PMI (133).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for PMI (133).jpg: Low Risk
# HB (209).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for HB (209).jpg: Low Risk
# Normal (380).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Normal (380).jpg: Low Risk
# PMI (164).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for PMI (164).jpg: Low Risk
# PMI (85).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for PMI (85).jpg: Low Risk
# Normal (729).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Normal (729).jpg: Low Risk
# Binder1_Page_142.jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Binder1_Page_142.jpg: Low Risk
# Binder1_Page_195.jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Binder1_Page_195.jpg: Low Risk
# Binder1_Page_181.jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Binder1_Page_181.jpg: Low Risk
# HB   (29).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for HB   (29).jpg: Low Risk
# HB (248).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for HB (248).jpg: Low Risk
# Normal (284).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Normal (284).jpg: Low Risk
# HB (474).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for HB (474).jpg: Low Risk
# HB (531).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for HB (531).jpg: Low Risk
# COVID  (3).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for COVID  (3).jpg: Low Risk
# HB (230).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for HB (230).jpg: Low Risk
# Normal (706).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Normal (706).jpg: Low Risk
# HB   (165).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for HB   (165).jpg: Low Risk
# Binder1_Page_198.jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Binder1_Page_198.jpg: Low Risk
# HB (322).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for HB (322).jpg: Low Risk
# Binder1_Page_173.jpg
# 1/1 [==============================] - 0s 17ms/step
# [[0.2713841]]
# Prediction for Binder1_Page_173.jpg: Low Risk
# MI (13).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for MI (13).jpg: Low Risk
# HB   (51).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for HB   (51).jpg: Low Risk
# HB (271).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for HB (271).jpg: Low Risk
# HB (334).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for HB (334).jpg: Low Risk
# PMI  (15).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for PMI  (15).jpg: Low Risk
# Binder1_Page_013.jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Binder1_Page_013.jpg: Low Risk
# Normal (481).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Normal (481).jpg: Low Risk
# Binder1_Page_007.jpg
# 1/1 [==============================] - 0s 17ms/step
# [[0.2713841]]
# Prediction for Binder1_Page_007.jpg: Low Risk
# Normal (194).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Normal (194).jpg: Low Risk
# HB (226).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for HB (226).jpg: Low Risk
# Normal (340).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Normal (340).jpg: Low Risk
# Normal (8).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Normal (8).jpg: Low Risk
# Normal (655).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Normal (655).jpg: Low Risk
# Normal (205).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Normal (205).jpg: Low Risk
# Binder1_Page_211.jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Binder1_Page_211.jpg: Low Risk
# HB   (10).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for HB   (10).jpg: Low Risk
# PMI  (39).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for PMI  (39).jpg: Low Risk
# Normal (442).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Normal (442).jpg: Low Risk
# HB   (84).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for HB   (84).jpg: Low Risk
# PMI (130).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for PMI (130).jpg: Low Risk
# Normal (383).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Normal (383).jpg: Low Risk
# PMI (188).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for PMI (188).jpg: Low Risk
# Normal (415).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Normal (415).jpg: Low Risk
# Normal (550).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Normal (550).jpg: Low Risk
# Normal (100).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Normal (100).jpg: Low Risk
# PMI (167).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for PMI (167).jpg: Low Risk
# HB (359).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for HB (359).jpg: Low Risk
# PMI (171).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for PMI (171).jpg: Low Risk
# HB (420).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for HB (420).jpg: Low Risk
# Normal (792).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Normal (792).jpg: Low Risk
# HB   (149).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for HB   (149).jpg: Low Risk
# HB (532).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for HB (532).jpg: Low Risk
# HB (498).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for HB (498).jpg: Low Risk
# Normal (511).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Normal (511).jpg: Low Risk
# HB (477).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for HB (477).jpg: Low Risk
# Normal (842).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Normal (842).jpg: Low Risk
# Normal (835).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Normal (835).jpg: Low Risk
# PMI (151).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for PMI (151).jpg: Low Risk
# PMI (49).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for PMI (49).jpg: Low Risk
# Normal (161).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Normal (161).jpg: Low Risk
# PMI (106).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for PMI (106).jpg: Low Risk
# HB (284).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for HB (284).jpg: Low Risk
# Normal (95).jpg
# 1/1 [==============================] - 0s 17ms/step
# [[0.2713841]]
# Prediction for Normal (95).jpg: Low Risk
# Normal (527).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Normal (527).jpg: Low Risk
# HB (504).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for HB (504).jpg: Low Risk
# PMI  (19).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for PMI  (19).jpg: Low Risk
# HB (292).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for HB (292).jpg: Low Risk
# HB (416).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for HB (416).jpg: Low Risk
# Normal (570).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Normal (570).jpg: Low Risk
# Normal (823).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Normal (823).jpg: Low Risk
# HB   (67).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for HB   (67).jpg: Low Risk
# MI (25).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for MI (25).jpg: Low Risk
# HB (528).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for HB (528).jpg: Low Risk
# HB (197).jpg
# 1/1 [==============================] - 0s 21ms/step
# [[0.2713841]]
# Prediction for HB (197).jpg: Low Risk
# Binder1_Page_213.jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Binder1_Page_213.jpg: Low Risk
# HB   (88).jpg
# 1/1 [==============================] - 0s 21ms/step
# [[0.2713841]]
# Prediction for HB   (88).jpg: Low Risk
# Binder1_Page_207.jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Binder1_Page_207.jpg: Low Risk
# HB (314).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for HB (314).jpg: Low Risk
# Normal (40).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Normal (40).jpg: Low Risk
# PMI (184).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for PMI (184).jpg: Low Risk
# HB   (30).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for HB   (30).jpg: Low Risk
# Binder1_Page_011.jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Binder1_Page_011.jpg: Low Risk
# HB   (7).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for HB   (7).jpg: Low Risk
# Binder1_Page_005.jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Binder1_Page_005.jpg: Low Risk
# Normal (225).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Normal (225).jpg: Low Risk
# HB   (104).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for HB   (104).jpg: Low Risk
# MI (64).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for MI (64).jpg: Low Risk
# PMI (192).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for PMI (192).jpg: Low Risk
# Binder1_Page_171.jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Binder1_Page_171.jpg: Low Risk
# HB (494).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for HB (494).jpg: Low Risk
# HB (181).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for HB (181).jpg: Low Risk
# PMI (203).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for PMI (203).jpg: Low Risk
# HB (302).jpg
# 1/1 [==============================] - 0s 19ms/step
# [[0.2713841]]
# Prediction for HB (302).jpg: Low Risk
# HB (247).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for HB (247).jpg: Low Risk
# HB   (145).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for HB   (145).jpg: Low Risk
# Normal (635).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Normal (635).jpg: Low Risk
# HB (303).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for HB (303).jpg: Low Risk
# HB (246).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for HB (246).jpg: Low Risk
# MI (32).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for MI (32).jpg: Low Risk
# HB (354).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for HB (354).jpg: Low Risk
# Normal (232).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Normal (232).jpg: Low Risk
# HB   (27).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for HB   (27).jpg: Low Risk
# Binder1_Page_149.jpg
# 1/1 [==============================] - 0s 18ms/step
# [[0.2713841]]
# Prediction for Binder1_Page_149.jpg: Low Risk
# Binder1_Page_175.jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Binder1_Page_175.jpg: Low Risk
# MI (1).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for MI (1).jpg: Low Risk
# PMI (72).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for PMI (72).jpg: Low Risk
# Normal (224).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Normal (224).jpg: Low Risk
# Normal (16).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Normal (16).jpg: Low Risk
# Normal (361).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Normal (361).jpg: Low Risk
# MI (73).jpg
# 1/1 [==============================] - 0s 24ms/step
# [[0.2713841]]
# Prediction for MI (73).jpg: Low Risk
# Normal (623).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Normal (623).jpg: Low Risk
# Normal (336).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Normal (336).jpg: Low Risk
# Normal (41).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Normal (41).jpg: Low Risk
# Normal (766).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Normal (766).jpg: Low Risk
# MI (24).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for MI (24).jpg: Low Risk
# PMI  (4).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for PMI  (4).jpg: Low Risk
# Normal (859).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Normal (859).jpg: Low Risk
# HB   (129).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for HB   (129).jpg: Low Risk
# Normal (5).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Normal (5).jpg: Low Risk
# HB (381).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for HB (381).jpg: Low Risk
# Normal (208).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Normal (208).jpg: Low Risk
# HB (417).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for HB (417).jpg: Low Risk
# HB (293).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for HB (293).jpg: Low Risk
# HB (339).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for HB (339).jpg: Low Risk
# Normal (176).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Normal (176).jpg: Low Risk
# Normal (526).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Normal (526).jpg: Low Risk
# HB (440).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for HB (440).jpg: Low Risk
# Normal (249).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Normal (249).jpg: Low Risk
# HB (456).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for HB (456).jpg: Low Risk
# HB (378).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for HB (378).jpg: Low Risk
# PMI (150).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for PMI (150).jpg: Low Risk
# MI (49).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for MI (49).jpg: Low Risk
# Normal (793).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Normal (793).jpg: Low Risk
# HB (421).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for HB (421).jpg: Low Risk
# ...
# Normal (11).jpg
# 1/1 [==============================] - 0s 18ms/step
# [[0.2713841]]
# Prediction for Normal (11).jpg: Low Risk
# Normal (409).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Normal (409).jpg: Low Risk
# PMI (194).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for PMI (194).jpg: Low Risk
# Normal (235).jpg
# 1/1 [==============================] - 0s 17ms/step
# [[0.2713841]]
# Prediction for Normal (235).jpg: Low Risk
# Normal (370).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Normal (370).jpg: Low Risk
# Normal (720).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Normal (720).jpg: Low Risk
# Normal (798).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Normal (798).jpg: Low Risk
# Normal (262).jpg
# 1/1 [==============================] - 0s 17ms/step
# [[0.2713841]]
# Prediction for Normal (262).jpg: Low Risk
# Normal (645).jpg
# 1/1 [==============================] - 0s 17ms/step
# [[0.2713841]]
# Prediction for Normal (645).jpg: Low Risk
# Normal (429).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Normal (429).jpg: Low Risk
# Normal (583).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Normal (583).jpg: Low Risk
# HB   (163).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for HB   (163).jpg: Low Risk
# Normal (757).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Normal (757).jpg: Low Risk
# Normal (307).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Normal (307).jpg: Low Risk
# HB (324).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for HB (324).jpg: Low Risk
# HB   (57).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for HB   (57).jpg: Low Risk
# HB (277).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for HB (277).jpg: Low Risk
# HB (298).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for HB (298).jpg: Low Risk
# HB   (122).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for HB   (122).jpg: Low Risk
# HB (220).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for HB (220).jpg: Low Risk
# Normal (346).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Normal (346).jpg: Low Risk
# Normal (31).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Normal (31).jpg: Low Risk
# PMI (55).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for PMI (55).jpg: Low Risk
# PMI  (44).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for PMI  (44).jpg: Low Risk
# HB   (16).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for HB   (16).jpg: Low Risk
# Normal (595).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Normal (595).jpg: Low Risk
# Normal (628).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Normal (628).jpg: Low Risk
# Normal (782).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Normal (782).jpg: Low Risk
# Normal (278).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Normal (278).jpg: Low Risk
# Normal (297).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Normal (297).jpg: Low Risk
# Normal (444).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Normal (444).jpg: Low Risk
# Normal (151).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Normal (151).jpg: Low Risk
# PMI (79).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for PMI (79).jpg: Low Risk
# Binder1_Page_072.jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Binder1_Page_072.jpg: Low Risk
# Normal (690).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Normal (690).jpg: Low Risk
# Binder1_Page_066.jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Binder1_Page_066.jpg: Low Risk
# Binder1_Page_099.jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Binder1_Page_099.jpg: Low Risk
# Normal (805).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Normal (805).jpg: Low Risk
# Binder1_Page_106.jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Binder1_Page_106.jpg: Low Risk
# HB   (118).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for HB   (118).jpg: Low Risk
# HB (308).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for HB (308).jpg: Low Risk
# Normal (794).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Normal (794).jpg: Low Risk
# Normal (281).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Normal (281).jpg: Low Risk
# Normal (452).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Normal (452).jpg: Low Risk
# HB (534).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for HB (534).jpg: Low Risk
# COVID  (6).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for COVID  (6).jpg: Low Risk
# HB (471).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for HB (471).jpg: Low Risk
# HB (535).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for HB (535).jpg: Low Risk
# Normal (453).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Normal (453).jpg: Low Risk
# COVID  (7).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for COVID  (7).jpg: Low Risk
# PMI (121).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for PMI (121).jpg: Low Risk
# HB   (95).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for HB   (95).jpg: Low Risk
# HB (470).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for HB (470).jpg: Low Risk
# Normal (516).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Normal (516).jpg: Low Risk
# HB (309).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for HB (309).jpg: Low Risk
# PMI (199).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for PMI (199).jpg: Low Risk
# HB (427).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for HB (427).jpg: Low Risk
# PMI (176).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for PMI (176).jpg: Low Risk
# Binder1_Page_116.jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Binder1_Page_116.jpg: Low Risk
# HB   (119).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for HB   (119).jpg: Low Risk
# PMI (81).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for PMI (81).jpg: Low Risk
# Normal (804).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Normal (804).jpg: Low Risk
# Normal (557).jpg
# 1/1 [==============================] - 0s 17ms/step
# [[0.2713841]]
# Prediction for Normal (557).jpg: Low Risk
# Normal (107).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Normal (107).jpg: Low Risk
# Normal (384).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Normal (384).jpg: Low Risk
# Normal (691).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Normal (691).jpg: Low Risk
# Binder1_Page_062.jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Binder1_Page_062.jpg: Low Risk
# PMI (97).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for PMI (97).jpg: Low Risk
# Binder1_Page_076.jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Binder1_Page_076.jpg: Low Risk
# HB (489).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for HB (489).jpg: Low Risk
# Normal (500).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Normal (500).jpg: Low Risk
# HB   (83).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for HB   (83).jpg: Low Risk
# Normal (853).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Normal (853).jpg: Low Risk
# PMI (137).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for PMI (137).jpg: Low Risk
# Normal (629).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Normal (629).jpg: Low Risk
# HB   (17).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for HB   (17).jpg: Low Risk
# MI (55).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for MI (55).jpg: Low Risk
# Normal (594).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Normal (594).jpg: Low Risk
# Normal (717).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Normal (717).jpg: Low Risk
# HB (364).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for HB (364).jpg: Low Risk
# Binder1_Page_063.jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Binder1_Page_063.jpg: Low Risk
# Normal (469).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Normal (469).jpg: Low Risk
# HB   (40).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for HB   (40).jpg: Low Risk
# HB   (174).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for HB   (174).jpg: Low Risk
# PMI  (12).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for PMI  (12).jpg: Low Risk
# Binder1_Page_088.jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Binder1_Page_088.jpg: Low Risk
# HB (333).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for HB (333).jpg: Low Risk
# Normal (605).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Normal (605).jpg: Low Risk
# HB   (56).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for HB   (56).jpg: Low Risk
# HB   (162).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for HB   (162).jpg: Low Risk
# Normal (756).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Normal (756).jpg: Low Risk
# HB (325).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for HB (325).jpg: Low Risk
# Normal (428).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Normal (428).jpg: Low Risk
# Normal (582).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Normal (582).jpg: Low Risk
# MI (43).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for MI (43).jpg: Low Risk
# Normal (26).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Normal (26).jpg: Low Risk
# HB (237).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for HB (237).jpg: Low Risk
# HB   (135).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for HB   (135).jpg: Low Risk
# HB (372).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for HB (372).jpg: Low Risk
# Normal (214).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Normal (214).jpg: Low Risk
# PMI  (24).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for PMI  (24).jpg: Low Risk
# HB   (142).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for HB   (142).jpg: Low Risk
# HB (240).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for HB (240).jpg: Low Risk
# MI (34).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for MI (34).jpg: Low Risk
# HB (539).jpg
# 1/1 [==============================] - 0s 17ms/step
# [[0.2713841]]
# Prediction for HB (539).jpg: Low Risk
# HB (186).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for HB (186).jpg: Low Risk
# HB (217).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for HB (217).jpg: Low Risk
# Normal (371).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Normal (371).jpg: Low Risk
# MI (63).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for MI (63).jpg: Low Risk
# HB   (21).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for HB   (21).jpg: Low Risk
# PMI (195).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for PMI (195).jpg: Low Risk
# MI (7).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for MI (7).jpg: Low Risk
# HB (344).jpg
# 1/1 [==============================] - 0s 17ms/step
# [[0.2713841]]
# Prediction for HB (344).jpg: Low Risk
# HB   (103).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for HB   (103).jpg: Low Risk
# HB (201).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for HB (201).jpg: Low Risk
# MI (75).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for MI (75).jpg: Low Risk
# Binder1_Page_075.jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Binder1_Page_075.jpg: Low Risk
# Binder1_Page_061.jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Binder1_Page_061.jpg: Low Risk
# HB (313).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for HB (313).jpg: Low Risk
# HB (256).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for HB (256).jpg: Low Risk
# MI (22).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for MI (22).jpg: Low Risk
# HB   (60).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for HB   (60).jpg: Low Risk
# Normal (824).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Normal (824).jpg: Low Risk
# Normal (577).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Normal (577).jpg: Low Risk
# Normal (598).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Normal (598).jpg: Low Risk
# MI (59).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for MI (59).jpg: Low Risk
# HB (450).jpg
# 1/1 [==============================] - 0s 17ms/step
# [[0.2713841]]
# Prediction for HB (450).jpg: Low Risk
# Normal (473).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for Normal (473).jpg: Low Risk
# MI (18).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for MI (18).jpg: Low Risk
# HB (391).jpg
# 1/1 [==============================] - 0s 16ms/step
# [[0.2713841]]
# Prediction for HB (391).jpg: Low Risk
# Normal (561).jpg
# 1/1 [==============================] - 0s 15ms/step
# [[0.2713841]]
# Prediction for Normal (561).jpg: Low Risk

# %%
import cv2
import numpy as np

# Load the image
img = cv2.imread('Dataset/ECG Images of COVID-19 Patients (250)/Binder1_Page_051.jpg')


## (1) Convert to gray, and threshold
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
th, threshed = cv2.threshold(gray, 240, 255, cv2.THRESH_BINARY_INV)

## (2) Morph-op to remove noise
kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (11,11))
morphed = cv2.morphologyEx(threshed, cv2.MORPH_CLOSE, kernel)

## (3) Find the max-area contour
cnts = cv2.findContours(morphed, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)[-2]
cnt = sorted(cnts, key=cv2.contourArea)[-1]

## (4) Crop and save it
x,y,w,h = cv2.boundingRect(cnt)
dst = img[y:y+h, x:x+w]
cv2.imwrite("001.png", dst)
# Out:
# True
